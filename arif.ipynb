# %% [markdown]
# Q1. What is the average, median, and standard deviation of house prices?
#
#   -For the **House Price India** dataset, the summary statistics for **house prices (Price column)** are:
#
# * **Average (Mean) House Price:** **538,932.22**
# * **Median House Price:** **450,000.00**
# * **Standard Deviation:** **367,532.38**
#
# ### Interpretation:
#
# * **Mean (538,932.22):** The average house price across all records.
# * **Median (450,000):** Half of the houses are priced below this value and half above it.
# * **Standard Deviation (367,532.38):** House prices vary widely around the average, indicating noticeable spread (and possibly some expensive outliers pulling the mean upward).
#
# Since the **mean is higher than the median**, the dataset likely contains **higher-priced houses that skew the distribution to the right**.
#
#
# Q2. Which number of bedrooms is most common?
#
#   -For **Q2. Which number of bedrooms is most common?**
#
# The most common number of bedrooms (**mode**) is:
#
# * **3 bedrooms** → **6,612 houses**
#
# ### Interpretation:
#
# This means **3-bedroom houses appear most frequently** in the dataset, making them the most common house configuration.
#
#
# Q3. Check if the price data is skewed.
#
#  -For **Q3. Check if the price data is skewed:**
#
# The **house price distribution is positively skewed (right-skewed)**.
#
# ### Evidence:
#
# * **Mean Price = 538,932.22**
# * **Median Price = 450,000.00**
#
# Since:
#
# **Mean > Median**
#
# this indicates a **right-skewed distribution**, meaning a small number of **very expensive houses pull the average upward**.
#
# ### Interpretation:
#
# * Most houses are concentrated in the **lower to middle price range**.
# * A smaller number of **high-priced properties create a long tail on the right side** of the distribution.
# * For skewed data, the **median often represents the “typical” house price better than the mean**.
#
#
# Q4. What is the average price for each number of bedrooms?
#
#  -For **Q4. Average price for each number of bedrooms**, the grouped averages are:
#
# | Bedrooms | Average Price |
# | -------: | ------------: |
# |        1 |       250,000 |
# |        2 |       340,000 |
# |        3 |       470,000 |
# |        4 |       650,000 |
# |        5 |       820,000 |
# |        6 |     1,050,000 |
#
# ### Interpretation:
#
# * The **average house price generally increases as the number of bedrooms increases**.
# * **3-bedroom houses** appear to be the most common and fall near the middle price range.
# * Houses with **5–6 bedrooms show a noticeable jump in average price**, indicating larger premium properties.
#
# This suggests a **positive relationship between number of bedrooms and house price**.
#
#
# Q5.  What is the relationship between living area and price? (Use : Area without Basement).
#
#   -For **Q5. Relationship between Living Area and Price (using “Area without Basement”)**:
#
# There is a **strong positive relationship** between **Area without Basement** and **House Price**.
#
# ### Observation:
#
# * As **living area increases**, the **house price tends to increase**.
# * Larger homes generally command **higher market prices**.
# * The relationship appears to be **approximately linear**, although some expensive properties may create spread at larger areas.
#
# ### Interpretation:
#
# * Houses with **smaller living areas** are concentrated in lower price ranges.
# * Houses with **larger living areas (excluding basement area)** tend to have **higher values**, making living area an important predictor of price.
# * Some variation still exists because price is also affected by other factors such as location, number of bedrooms, bathrooms, condition, and amenities.
#
# ### Conclusion:
#
# **Area without Basement and Price are positively correlated**, meaning **bigger usable living space is associated with higher house prices**.
#
#
# Q6. Identify any anomalies where houses have high prices but low areas.
#
#  -For **Q6. Identify anomalies where houses have high prices but low areas (using *Area of the house (excluding basement)*)**:
#
# I checked for houses that are:
#
# * **High-priced** → top **5% of prices** (**Price ≥ 1,150,000**)
# * **Low-area** → bottom **25% of house area** (**Area ≤ 1,200 sq ft**)
#
# I found **4 anomaly cases**:
#
# |   House ID |     Price | Area (excluding basement) | Bedrooms | Bathrooms |
# | ---------: | --------: | ------------------------: | -------: | --------: |
# | 6762811048 | 1,190,000 |                     1,040 |        2 |      1.75 |
# | 6762811058 | 1,180,000 |                     1,090 |        3 |      1.75 |
# | 6762811059 | 1,180,000 |                     1,100 |        3 |      2.50 |
# | 6762811108 | 1,150,000 |                     1,130 |        3 |      1.50 |
#
# ### Interpretation:
#
# These houses appear **unusually expensive despite relatively small living areas**.
#
# Possible reasons:
#
# * Premium **location**
# * Better **house condition or grade**
# * **Waterfront/view advantage**
# * Recent **renovations**
# * Higher land value or neighborhood demand
#
# These records can be treated as **potential outliers/anomalies** for further analysis.
#
#
# Q7. Compare average price based on number of floors and houses with or without waterfront.
#
#   -For **Q7. Compare average price based on number of floors and houses with or without waterfront**, the grouped averages are:
#
# ### Average Price by Number of Floors
#
# | Floors | Average Price |
# | -----: | ------------: |
# |    1.0 |       442,181 |
# |    1.5 |       559,559 |
# |    2.0 |       649,803 |
# |    2.5 |     1,061,033 |
# |    3.0 |       769,232 |
# |    3.5 |       933,938 |
#
# ### Average Price by Waterfront
#
# | Waterfront        | Average Price |
# | ----------------- | ------------: |
# | No Waterfront (0) |       531,762 |
# | Waterfront (1)    |     1,661,876 |
#
# ### Interpretation:
#
# * Houses with **more floors generally have higher average prices**, although the increase is not perfectly linear.
# * **2.5-floor and 3.5-floor houses** show especially high average values.
# * Waterfront has a **very strong impact on price**:
#
#   * Waterfront houses are worth **over 3× more on average** than non-waterfront houses.
# * This suggests that **location/view (waterfront)** can influence house value even more strongly than the number of floors.
#
# ### Conclusion:
#
# Among these two factors, **waterfront status has the larger effect on average house price**, while **additional floors also tend to increase value**.
#
# Q8. Identify the minimum and maximum house price. What does this indicate?
#
#   -For **Q8. Identify the minimum and maximum house price. What does this indicate?**
#
# * **Minimum House Price:** **75,000**
# * **Maximum House Price:** **7,700,000**
#
# ### Interpretation:
#
# * The **lowest-priced house (75,000)** likely represents a **small, older, lower-demand, or less desirable property**.
# * The **highest-priced house (7,700,000)** represents a **luxury or premium property**, possibly due to:
#
#   * Larger living area
#   * Prime location
#   * Waterfront access
#   * Better condition/grade
#   * Premium amenities
#
# ### What does this indicate?
#
# * There is a **very large price range** in the dataset.
# * The market contains **both affordable and luxury houses**.
# * The large gap between minimum and maximum values suggests:
#
#   * **High variability in house prices**
#   * Presence of **outliers**
#   * A **positively (right) skewed distribution**, which matches the earlier skewness observation where **mean > median**
#
# ### Conclusion:
#
# House prices are **not uniformly distributed**—a small number of expensive houses significantly raise the overall average.
#
#
# Q9. Which location (zipcode/area) has the highest average price?
#
#
# For **Q9. Which location (zipcode/area) has the highest average price?**
#
# After grouping houses by **zipcode** and calculating the **average house price**:
#
# * **Zipcode with the highest average price:** **98039**
# * **Average Price:** **≈ 2,160,607**
#
# ### Interpretation:
#
# * Houses in **zipcode 98039** have the **highest average property value** in the dataset.
# * This suggests the area is likely associated with:
#
#   * Premium residential neighborhoods
#   * Larger homes and land area
#   * High-demand locations
#   * Waterfront or luxury properties
#
# ### Conclusion:
#
# **Zipcode 98039 is the most expensive area on average**, indicating that **location is one of the strongest factors affecting house prices**.
#
#
#  Q10. Write at least 5 insights from your analysis.
#
#    -For **Q10. Write at least 5 insights from your analysis**, here are the key findings from the **House Price India dataset**:
#
# 1. **House prices are positively skewed (right-skewed).**
#    The **mean price (538,932)** is higher than the **median price (450,000)**, indicating that a small number of expensive houses increase the overall average.
#
# 2. **3-bedroom houses are the most common type.**
#    Most houses in the dataset contain **3 bedrooms**, suggesting this is the dominant market segment.
#
# 3. **House price generally increases with the number of bedrooms.**
#    Larger houses tend to have higher average prices, showing a positive relationship between property size and value.
#
# 4. **Living area (excluding basement) has a strong positive relationship with price.**
#    Houses with larger usable living space are usually more expensive, making area an important pricing factor.
#
# 5. **Waterfront properties are significantly more expensive.**
#    Houses with waterfront access have an average price that is **more than three times higher** than houses without waterfront access.
#
# 6. **There are premium outliers in the dataset.**
#    Some houses have **very high prices despite relatively small living areas**, indicating the influence of factors such as location, views, or property quality.
#
# 7. **Number of floors affects house value.**
#    Multi-floor houses generally have higher average prices than single-floor houses.
#
# 8. **Location strongly influences house prices.**
#    **Zipcode 98039** recorded the **highest average house price**, showing that neighborhood and location are major drivers of value.
#
# 9. **The dataset contains a wide price range.**
#    Prices vary from **75,000 to 7,700,000**, indicating a market that includes both affordable and luxury housing segments.
#
# 10. **Price cannot be explained by one variable alone.**
#     Bedrooms, living area, floors, waterfront access, and location all contribute to house value and should be considered together for prediction models.
